# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/tuansunday05/fe8kv9.git

# %%
import os
os.chdir(os.path.curdir + '/fe8kv9')
HOME = os.getcwd()
print(HOME)

# %%
# !mkdir -p {HOME}/weights
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !mkdir -p {HOME}/data
SOURCE_IMAGE_PATH = f"{HOME}/camera3_A_102.png"

# %%
# !python detect.py --weights {HOME}/weights/gelan-e.pt --conf 0.2 --source {HOME}/data/camera3_A_102.png --device 0

# %%
from PIL import Image

# %%
Image.open(f"{HOME}/runs/detect/exp/camera3_A_102.png")

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.2 --source {HOME}/data/camera3_A_102.png --device 0

# %%
Image.open(f"{HOME}/runs/detect/exp2/camera3_A_102.png")

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow

rf = Roboflow(api_key='Iay6tNm46YcmdAQwn2Kj')
project = rf.workspace('fe8k-z7cca').project('fe8k')
dataset = project.version(1).download('yolov7')

# %%
# !python train_dual.py \
--batch 16 --epochs 250 --img 640 --device 0,1 --min-items 0 \
--data FE8K-1/data.yaml \
--weights {HOME}/weights/yolov9-e.pt \
--cfg models/detect/yolov9-e.yaml \
--hyp hyp.scratch-high.yaml

# %%
# !python train_dual.py --workers 2 --device 0,1 \
--sync-bn --batch 8 --data FE8K-1/data.yaml --img 640 \
--cfg models/detect/yolov9-e.yaml \
--weights {HOME}/weights/yolov9-e.pt\
--name yolov9-e\
--hyp hyp.scratch-high.yaml --min-items 0 --epochs 250 \
--close-mosaic 0
